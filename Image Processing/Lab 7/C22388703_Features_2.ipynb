# %% [markdown]
# # Features 2
# ### Finding corners and interesting parts of the image.
#
# 1. Open “Sudoku.jpg”;
# 2. Create a Harris corner image for this image;
# 3. Use Shi-Tomasi to find the location of the strongest corners.
# Advanced Task:
# Plot the Shi-Tomasi corners on the Harris image.

# %%
import cv2 as cv2
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import image as image
import math

I = cv2.imread("sudoku.jpg")

I = cv2.cvtColor(I, cv2.COLOR_BGR2RGB)
Original = I.copy()

plt.imshow(I)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(573.5), np.float64(535.5), np.float64(-0.5))

# %%
G = cv2.cvtColor(I, cv2.COLOR_RGB2GRAY)

H = cv2.cornerHarris(G,blockSize=5,ksize=3,k=0.04)

Corners = cv2.goodFeaturesToTrack(G,maxCorners=100, qualityLevel=0.1,minDistance=10)

print(Corners)

for i in Corners:
    x, y = i.ravel()
    cv2.circle(img = H, center = (int(x),int(y)), radius = 1, color = (255,0,0), thickness = 10)

plt.imshow(H)
plt.axis('off')
# Out:
# [[[426. 433.]]
#
#  [[488. 366.]]
#
#  [[486. 276.]]
#
#  [[442. 436.]]
#
#  [[375. 477.]]
#
#  [[309. 229.]]
#
#  [[274. 277.]]
#
#  [[427. 334.]]
#
#  [[474. 372.]]
#
#  [[495. 241.]]
#
#  [[248. 515.]]
#
#  [[319. 427.]]
#
#  [[150.  30.]]
#
#  [[323. 232.]]
#
#  [[379. 329.]]
#
#  [[100. 384.]]
#
#  [[383. 501.]]
#
#  [[480. 482.]]
#
#  [[169.  20.]]
#
#  [[501. 343.]]
#
#  [[ 44. 185.]]
#
#  [[510. 335.]]
#
#  [[507. 281.]]
#
#  [[315. 441.]]
#
#  [[149. 262.]]
#
#  [[220. 271.]]
#
#  [[489. 325.]]
#
#  [[126.  35.]]
#
#  [[210. 339.]]
#
#  [[260. 388.]]
#
#  [[467. 116.]]
#
#  [[515. 391.]]
#
#  [[255. 181.]]
#
#  [[436. 445.]]
#
#  [[182. 247.]]
#
#  [[158. 447.]]
#
#  [[482.  38.]]
#
#  [[105. 123.]]
#
#  [[312.  73.]]
#
#  [[475. 305.]]
#
#  [[264. 157.]]
#
#  [[511. 455.]]
#
#  [[205. 313.]]
#
#  [[319. 284.]]
#
#  [[417. 312.]]
#
#  [[104. 222.]]
#
#  [[505. 247.]]
#
#  [[384. 471.]]
#
#  [[525. 469.]]
#
#  [[511. 314.]]
#
#  [[410. 511.]]
#
#  [[102. 369.]]
#
# ...
